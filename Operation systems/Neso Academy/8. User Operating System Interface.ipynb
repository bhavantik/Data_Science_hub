# %% [markdown]
# # 8. User Operating System Interface
#
# Operating System: User Operating System Interface
# Topics discussed:
# 1. Command Line Interface (CLI).
# 2. Graphical User Interface (GUI).
# 3. Creating a directory using the command line interface in Linux OS.
# 4. Deleting a directory using the command line interface in Linux OS.
# 5. Creating a directory using the command line interface in Windows OS.
# 6. Deleting a directory using the command line interface in Windows OS.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - winows --> cmd
# - linux --> terminal
#
# #### terminal command
# - pwd
# - cd folder_path
# - mkdir myfile1
# - ls
# - rm -rf myfile1
#
# #### cmd
# - cd
# - cd folder_path
# - mkdir myfile1
# - dir
# - rmdir myfile1
