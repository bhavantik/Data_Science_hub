# %% [markdown]
# # 34. Threading Issues [fork() & exec() System Calls]
# Topics discussed:
# 1) Threading issues related to fork() and exec() system calls.
# 2) Two versions of the fork.
# 3) Which version of the fork to use and when.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
