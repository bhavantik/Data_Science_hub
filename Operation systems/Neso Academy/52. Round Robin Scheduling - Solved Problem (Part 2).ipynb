# %% [markdown]
# # 52. Round Robin Scheduling - Solved Problem (Part 2)
# Topics discussed:
# 1) Calculation of Average Turnaround Time and Average Waiting Time from Gantt Chart for Round Robin Scheduling.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
