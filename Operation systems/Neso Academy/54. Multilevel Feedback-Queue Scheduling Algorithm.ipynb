# %% [markdown]
# # 54. Multilevel Feedback-Queue Scheduling Algorithm
# Topics discussed:
# 1) Multilevel Feedback-Queue Scheduling Algorithm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
