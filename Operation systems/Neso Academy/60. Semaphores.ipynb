# %% [markdown]
# # 60. Semaphores
# Operating System: Semaphores
# Topics discussed:
# 1. Semaphores.
# 2. wait () and signal () operations.
# 3. Binary Semaphores.
# 4. Counting Semaphores.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
