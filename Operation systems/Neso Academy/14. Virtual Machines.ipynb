# %% [markdown]
# # 14. Virtual Machines
#
# - Topics discussed:
# 1. Virtual Machines.
# 2. The fundamental idea of a virtual machine.
# 3. Virtual machine implementation.
# 4. Virtual machine user mode & virtual machine kernel mode.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
