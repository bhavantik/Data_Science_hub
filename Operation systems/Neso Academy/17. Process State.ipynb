# %% [markdown]
# # 17. Process State
# - Topics discussed:
# 1) New state.
# 2) Running State.
# 3) Waiting State.
# 4) Ready State.
# 5) Terminated State.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
