# %% [markdown]
# # 70. Process Synchronization - Problem 5

# %% [markdown]
# Topics discussed:
# 1. A solved problem on Process Synchronization from GATE 1998.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
