# %% [markdown]
# Here’s a summary of **TechWorld with Nana – Docker Tutorial 2: "What is a Docker Container? Docker Demo"**
#
# ---
#
# ### 📺 **Video:** *What is a Docker Container? Docker Demo*
#
# 🔗 [Watch here](https://www.youtube.com/watch?v=YFl2mCHdv24)
#
# ---
#
# ### 🧠 **Summary of Key Concepts & Demo**
#
# ---
#
# ### 🔹 1. **What Is a Docker Container (Reinforced)?**
#
# * A **Docker container** is:
#
#   * A **lightweight**, standalone, executable software package.
#   * Includes **everything needed** to run a program: code, runtime, libraries, environment variables, and config files.
# * It’s created from a **Docker image** and runs in **isolation** from the host system and other containers.
#
# 🧪 Think of it as a **running process that behaves like a lightweight VM**, but much faster and more efficient.
#
# ---
#
# ### 🔹 2. **Demo Walkthrough: Running a Container**
#
# #### 🧩 Example Command
#
# ```bash
# docker run hello-world
# ```
#
# * **What it does:**
#
#   * Checks if `hello-world` image exists locally.
#   * If not, pulls it from Docker Hub.
#   * Creates a container from the image and runs it.
#   * Outputs a success message from inside the container.
#
# #### 🔄 Behind the scenes:
#
# * Docker uses:
#
#   * **Image → Container**
#   * Image is **read-only**
#   * Container is **read-write layer on top of the image**
#
# ---
#
# ### 🔹 3. **Inspecting Docker Containers**
#
# #### View Running Containers:
#
# ```bash
# docker ps
# ```
#
# #### View All Containers (including stopped):
#
# ```bash
# docker ps -a
# ```
#
# #### Remove a Container:
#
# ```bash
# docker rm <container_id>
# ```
#
# #### Remove an Image:
#
# ```bash
# docker rmi <image_id>
# ```
#
# ---
#
# ### 🔹 4. **Container Lifecycle**
#
# * **Created** → **Running** → **Stopped** → **Removed**
# * Once the process inside the container stops, the container stops too.
#
# ---
#
# ### 🔹 5. **Why Containers Matter in Real Life**
#
# * Developers can **test applications locally**, package them into containers, and deploy them to any system (e.g., GKE, ECS, Azure) without worrying about compatibility or environment differences.
#
# ---
#
# ### 🔹 6. **Summary Recap**
#
# * A Docker **container** is:
#
#   * A **running instance** of an image.
#   * **Ephemeral** by default (dies when process ends unless specified).
#   * Can be started, stopped, restarted, deleted.
#
# ---
#
# Would you like a side-by-side comparison between Docker and Kubernetes in the next summary? Or shall I continue with **Tutorial 3** in the series?
