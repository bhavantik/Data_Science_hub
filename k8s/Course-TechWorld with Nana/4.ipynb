# %% [markdown]
# Here’s a clear and concise summary of **TechWorld with Nana – Docker Tutorial 4: "8 Basic Docker Commands"**:
#
# ---
#
# ### 📺 **Video Title:**
#
# **8 Basic Docker Commands**
# 🔗 [Watch here](https://www.youtube.com/watch?v=Kyx2PsuwomE)
#
# ---
#
# ### 🧠 **Summary of the 8 Essential Docker Commands**
#
# These commands help you start working with Docker containers and images in real projects.
#
# ---
#
# ### 🔹 1. `docker pull`
#
# ```bash
# docker pull nginx
# ```
#
# * Downloads the specified image from **Docker Hub** to your local system.
# * Example: `nginx`, `ubuntu`, `mysql`.
#
# ---
#
# ### 🔹 2. `docker images`
#
# ```bash
# docker images
# ```
#
# * Lists all the Docker images you have **locally**.
# * Shows: repository name, tag, image ID, size, and creation date.
#
# ---
#
# ### 🔹 3. `docker run`
#
# ```bash
# docker run nginx
# ```
#
# * Runs a **container** from an image.
# * Options:
#
#   * `-d` → Run in detached mode (background)
#   * `-p` → Map ports (e.g., `-p 8080:80`)
#   * `--name` → Give a custom name to your container
#
# ✅ Example:
#
# ```bash
# docker run -d -p 8080:80 --name mynginx nginx
# ```
#
# ---
#
# ### 🔹 4. `docker ps`
#
# ```bash
# docker ps
# ```
#
# * Lists all **running containers**.
# * Use `docker ps -a` to include **stopped** containers.
#
# ---
#
# ### 🔹 5. `docker stop`
#
# ```bash
# docker stop <container_id_or_name>
# ```
#
# * Gracefully stops a running container.
#
# ---
#
# ### 🔹 6. `docker rm`
#
# ```bash
# docker rm <container_id_or_name>
# ```
#
# * Deletes a container (must be stopped first).
#
# 🧠 Tip: Combine both commands:
#
# ```bash
# docker stop mynginx && docker rm mynginx
# ```
#
# ---
#
# ### 🔹 7. `docker rmi`
#
# ```bash
# docker rmi <image_id_or_name>
# ```
#
# * Removes an image from your system.
# * Must not be used by any container.
#
# ---
#
# ### 🔹 8. `docker logs`
#
# ```bash
# docker logs <container_id_or_name>
# ```
#
# * Shows logs/output from a running container.
# * Helpful for debugging or checking startup info.
#
# ---
#
# ### 🧪 Bonus Tips from the Video:
#
# * Use `docker run -it ubuntu bash` to open an **interactive terminal** inside a container.
# * You can **chain commands** using `&&` to stop and remove containers together.
# * Prefer naming containers with `--name` for easier access and management.
#
# ---
#
# Would you like a quick **hands-on lab guide using these 8 commands** with exercises?
