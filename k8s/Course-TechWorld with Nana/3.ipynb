# %% [markdown]
# Here’s a detailed summary of **TechWorld with Nana – Docker Tutorial 3: "How to install Docker? Step by Step"**
#
# ---
#
# ### 📺 **Video Title:**
#
# **How to install Docker? Step by Step**
# 🔗 [Watch on YouTube](https://www.youtube.com/watch?v=FqzZBtqPVgM)
#
# ---
#
# ### 🧠 **Summary: Step-by-Step Docker Installation**
#
# ---
#
# ### 🔹 1. **Prerequisites**
#
# * Supported Operating Systems:
#
#   * Windows 10/11 (Pro or Enterprise) with **WSL 2**
#   * macOS
#   * Most major Linux distros (Ubuntu, CentOS, etc.)
#
# ---
#
# ### 🔹 2. **For Windows Installation (Docker Desktop)**
#
# #### ✅ Steps:
#
# 1. **Download Docker Desktop**
#
#    * Visit [https://www.docker.com/products/docker-desktop](https://www.docker.com/products/docker-desktop)
#    * Choose Windows version.
#
# 2. **Install Docker Desktop**
#
#    * Double-click the `.exe` installer and follow the setup.
#    * Ensure **“Use WSL 2 instead of Hyper-V”** is selected (WSL 2 gives better performance).
#
# 3. **Install WSL 2 (if not already installed)**
#
#    ```bash
#    wsl --install
#    ```
#
#    * Restart system if prompted.
#
# 4. **Start Docker Desktop**
#
#    * Launch it from the start menu.
#    * It will run as a background service.
#
# 5. **Verify Docker Installation**
#
#    ```bash
#    docker --version
#    docker run hello-world
#    ```
#
# ---
#
# ### 🔹 3. **For macOS Installation (Docker Desktop)**
#
# #### ✅ Steps:
#
# 1. Download Docker Desktop for Mac from the official site.
# 2. Install the `.dmg` file and drag it to the Applications folder.
# 3. Run Docker Desktop.
# 4. Verify with:
#
#    ```bash
#    docker version
#    docker run hello-world
#    ```
#
# ---
#
# ### 🔹 4. **For Ubuntu/Linux Installation**
#
# #### ✅ Commands:
#
# ```bash
# sudo apt update
# sudo apt install apt-transport-https ca-certificates curl software-properties-common
#
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /usr/share/keyrings/docker-archive-keyring.gpg
#
# echo "deb [arch=amd64 signed-by=/usr/share/keyrings/docker-archive-keyring.gpg] https://download.docker.com/linux/ubuntu stable" |
# sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
#
# sudo apt update
# sudo apt install docker-ce
# ```
#
# #### ✅ Post-install:
#
# ```bash
# sudo systemctl start docker
# sudo systemctl enable docker
# sudo docker run hello-world
# ```
#
# (Optional) Run Docker as non-root:
#
# ```bash
# sudo usermod -aG docker $USER
# newgrp docker
# ```
#
# ---
#
# ### 🔹 5. **Troubleshooting Tips**
#
# * Make sure **virtualization** is enabled in BIOS.
# * Restart Docker Desktop or system if installation doesn’t reflect.
# * For WSL 2 issues, update kernel or install correct WSL version using:
#
#   ```bash
#   wsl --update
#   ```
#
# ---
#
# ### 🧪 Summary Recap:
#
# * Docker installation varies slightly across OS, but **Docker Desktop** is the easiest method for Windows/Mac.
# * On Linux, use **Docker CE** (Community Edition) via APT/YUM.
# * After installation, test with:
#
#   ```bash
#   docker run hello-world
#   ```
#
# ---
#
# Would you like a **cheatsheet of most-used Docker commands** next, or shall I continue with **Docker Tutorial 4: Docker Images Explained**?
